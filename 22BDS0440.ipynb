# %% [markdown]
# <a href="https://colab.research.google.com/github/YashMidha/EDA_22BDS0440/blob/main/22BDS0440.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # YASH MIDHA - 22BDS0440

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Importing Dataset

# %%
url = 'https://raw.githubusercontent.com/salemprakash/EDA/main/Data/school93_98.csv'

# %%
data = pd.read_csv(url)

# %%
data.head()
# Out:
#    rownames  distid  schid      lunch  enrol   exppp      math4  year  y93  \
# 0         1   34010      1  39.799999  256.0  2506.0  46.599998  1993    1
# 1         2   34010      1  35.000000  248.0  2870.0  44.700001  1994    0
# 2         3   34010      1  36.590000  244.0  4176.0  86.500000  1995    0
# 3         4   34010      1  40.549999  247.0  4333.0  84.300003  1996    0
# 4         5   34010      1  49.490002  291.0  3666.0  83.800003  1997    0
#
#    y94  y95  y96  y97  y98        rexpp   found    lenrol    lrexpp  lavgrexpp
# 0    0    0    0    0    0  2783.480957     NaN  5.545177  7.931458        NaN
# 1    1    0    0    0    0  3108.198486     NaN  5.513429  8.041799   7.988149
# 2    0    1    0    0    0  4397.953125  4478.0  5.497168  8.388894   8.230331
# 3    0    0    1    0    0  4432.418945  4754.0  5.509388  8.396701   8.392805
# 4    0    0    0    1    0  3666.000000  5032.0  5.673323  8.206857   8.306277

# %%
data.tail()
# Out:
#        rownames  distid  schid  lunch  enrol  exppp      math4  year  y93  \
# 10663     10664   63200   7725    NaN  137.0    NaN  72.000000  1994    0
# 10664     10665   63200   7725    NaN  135.0    NaN  62.500000  1995    0
# 10665     10666   63200   7725    NaN  124.0    NaN  63.200001  1996    0
# 10666     10667   63200   7725    NaN  129.0    NaN  78.900002  1997    0
# 10667     10668   63200   7725    0.0  132.0    NaN  87.000000  1998    0
#
#        y94  y95  y96  y97  y98  rexpp   found    lenrol  lrexpp  lavgrexpp
# 10663    1    0    0    0    0    NaN     NaN  4.919981     NaN        NaN
# 10664    0    1    0    0    0    NaN  8567.0  4.905275     NaN        NaN
# 10665    0    0    1    0    0    NaN  8720.0  4.820282     NaN        NaN
# 10666    0    0    0    1    0    NaN  8875.0  4.859812     NaN        NaN
# 10667    0    0    0    0    1    NaN  9029.0  4.882802     NaN        NaN

# %% [markdown]
# ## Summary Statistics

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10668 entries, 0 to 10667
# Data columns (total 19 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   rownames   10668 non-null  int64
#  1   distid     10668 non-null  int64
#  2   schid      10668 non-null  int64
#  3   lunch      10365 non-null  float64
#  4   enrol      10499 non-null  float64
#  5   exppp      9731 non-null   float64
#  6   math4      10565 non-null  float64
#  7   year       10668 non-null  int64
#  8   y93        10668 non-null  int64
#  9   y94        10668 non-null  int64
#  10  y95        10668 non-null  int64
#  11  y96        10668 non-null  int64
#  12  y97        10668 non-null  int64
#  13  y98        10668 non-null  int64
#  14  rexpp      9731 non-null   float64
#  15  found      7112 non-null   float64
#  16  lenrol     10499 non-null  float64
#  17  lrexpp     9731 non-null   float64
#  18  lavgrexpp  7517 non-null   float64
# ...

# %%
data.describe()
# Out:
#           rownames        distid         schid         lunch         enrol  \
# count  10668.00000  10668.000000  10668.000000  10365.000000  10499.000000
# mean    5334.50000  52873.061305   2963.074803     37.384330    417.613963
# std     3079.73067  23938.765714   2009.157208     25.347934    166.694982
# min        1.00000   1010.000000      1.000000      0.000000      7.000000
# 25%     2667.75000  33070.000000   1306.000000     16.360001    307.000000
# 50%     5334.50000  56010.000000   2562.500000     33.330002    405.000000
# 75%     8001.25000  75100.000000   4421.000000     54.169998    507.000000
# max    10668.00000  83070.000000   7725.000000    100.000000   1353.000000
#
#               exppp         math4          year           y93           y94  \
# count   9731.000000  10565.000000  10668.000000  10668.000000  10668.000000
# mean    3778.583702     58.445348   1995.500000      0.166667      0.166667
# ...

# %% [markdown]
# ## Data shape

# %%
shape = data.shape
print("rows:", shape[0])
print("columns:", shape[1])
# Out:
# rows: 10668
# columns: 18

# %% [markdown]
# ## Data Handling

# %%
# Dropping column rownames as it is unnecessary
data = data.drop('rownames', axis=1)

# %%
data.head()
# Out:
#    distid  schid      lunch  enrol   exppp      math4  year  y93  y94  y95  \
# 0   34010      1  39.799999  256.0  2506.0  46.599998  1993    1    0    0
# 1   34010      1  35.000000  248.0  2870.0  44.700001  1994    0    1    0
# 2   34010      1  36.590000  244.0  4176.0  86.500000  1995    0    0    1
# 3   34010      1  40.549999  247.0  4333.0  84.300003  1996    0    0    0
# 4   34010      1  49.490002  291.0  3666.0  83.800003  1997    0    0    0
#
#    y96  y97  y98        rexpp   found    lenrol    lrexpp  lavgrexpp
# 0    0    0    0  2783.480957     NaN  5.545177  7.931458        NaN
# 1    0    0    0  3108.198486     NaN  5.513429  8.041799   7.988149
# 2    0    0    0  4397.953125  4478.0  5.497168  8.388894   8.230331
# 3    1    0    0  4432.418945  4754.0  5.509388  8.396701   8.392805
# 4    0    1    0  3666.000000  5032.0  5.673323  8.206857   8.306277

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10668 entries, 0 to 10667
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   distid     10668 non-null  int64
#  1   schid      10668 non-null  int64
#  2   lunch      10365 non-null  float64
#  3   enrol      10499 non-null  float64
#  4   exppp      9731 non-null   float64
#  5   math4      10565 non-null  float64
#  6   year       10668 non-null  int64
#  7   y93        10668 non-null  int64
#  8   y94        10668 non-null  int64
#  9   y95        10668 non-null  int64
#  10  y96        10668 non-null  int64
#  11  y97        10668 non-null  int64
#  12  y98        10668 non-null  int64
#  13  rexpp      9731 non-null   float64
#  14  found      7112 non-null   float64
#  15  lenrol     10499 non-null  float64
#  16  lrexpp     9731 non-null   float64
#  17  lavgrexpp  7517 non-null   float64
# dtypes: float64(9), int64(9)
# memory usage: 1.5 MB

# %%
data.describe()
# Out:
#              distid         schid         lunch         enrol         exppp  \
# count  10668.000000  10668.000000  10365.000000  10499.000000   9731.000000
# mean   52873.061305   2963.074803     37.384330    417.613963   3778.583702
# std    23938.765714   2009.157208     25.347934    166.694982    923.798238
# min     1010.000000      1.000000      0.000000      7.000000    254.000000
# 25%    33070.000000   1306.000000     16.360001    307.000000   3155.500000
# 50%    56010.000000   2562.500000     33.330002    405.000000   3737.000000
# 75%    75100.000000   4421.000000     54.169998    507.000000   4278.500000
# max    83070.000000   7725.000000    100.000000   1353.000000  13581.000000
#
#               math4          year           y93           y94           y95  \
# count  10565.000000  10668.000000  10668.000000  10668.000000  10668.000000
# mean      58.445348   1995.500000      0.166667      0.166667      0.166667
# ...

# %%
data.shape
# Out:
# (10668, 18)

# %% [markdown]
# #### Observation

# %% [markdown]
# Removing the column - rownames consisting of the index values as it was unnessary.

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### 1. Data deduplication

# %%
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10663    False
# 10664    False
# 10665    False
# 10666    False
# 10667    False
# Length: 10668, dtype: bool

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Data has no duplicated row

# %%
data.shape
# Out:
# (10668, 18)

# %%
data = data.drop_duplicates()

# %%
data.shape
# Out:
# (10668, 18)

# %%
data.duplicated(subset=['distid', 'schid']).sum()
# Out:
# np.int64(8890)

# %% [markdown]
# #### Observation

# %% [markdown]
# 1. No row is entirely duplicated
# 2. Duplicates based on distid and schid does exist
# 2. Cannot remove duplicates based on distid and schid as otherwise the dataset will be dimish marginally

# %% [markdown]
# ### 2. Missing values

# %%
data.isnull()
# Out:
#        distid  schid  lunch  enrol  exppp  math4   year    y93    y94    y95  \
# 0       False  False  False  False  False  False  False  False  False  False
# 1       False  False  False  False  False  False  False  False  False  False
# 2       False  False  False  False  False  False  False  False  False  False
# 3       False  False  False  False  False  False  False  False  False  False
# 4       False  False  False  False  False  False  False  False  False  False
# ...       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 10663   False  False   True  False   True  False  False  False  False  False
# 10664   False  False   True  False   True  False  False  False  False  False
# 10665   False  False   True  False   True  False  False  False  False  False
# 10666   False  False   True  False   True  False  False  False  False  False
# 10667   False  False  False  False   True  False  False  False  False  False
#
# ...

# %%
data.isnull().sum()
# Out:
# distid          0
# schid           0
# lunch         303
# enrol         169
# exppp         937
# math4         103
# year            0
# y93             0
# y94             0
# y95             0
# y96             0
# y97             0
# y98             0
# rexpp         937
# found        3556
# lenrol        169
# lrexpp        937
# lavgrexpp    3151
# dtype: int64

# %%
data.head()
# Out:
#    distid  schid      lunch  enrol   exppp      math4  year  y93  y94  y95  \
# 0   34010      1  39.799999  256.0  2506.0  46.599998  1993    1    0    0
# 1   34010      1  35.000000  248.0  2870.0  44.700001  1994    0    1    0
# 2   34010      1  36.590000  244.0  4176.0  86.500000  1995    0    0    1
# 3   34010      1  40.549999  247.0  4333.0  84.300003  1996    0    0    0
# 4   34010      1  49.490002  291.0  3666.0  83.800003  1997    0    0    0
#
#    y96  y97  y98        rexpp   found    lenrol    lrexpp  lavgrexpp
# 0    0    0    0  2783.480957     NaN  5.545177  7.931458        NaN
# 1    0    0    0  3108.198486     NaN  5.513429  8.041799   7.988149
# 2    0    0    0  4397.953125  4478.0  5.497168  8.388894   8.230331
# 3    1    0    0  4432.418945  4754.0  5.509388  8.396701   8.392805
# 4    0    1    0  3666.000000  5032.0  5.673323  8.206857   8.306277

# %%
for col in data.columns:
  data[col].fillna(data[col].mean(), inplace=True)
# Out:
# /tmp/ipython-input-3365838668.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[col].fillna(data[col].mean(), inplace=True)

# %%
data.isnull().sum()
# Out:
# distid       0
# schid        0
# lunch        0
# enrol        0
# exppp        0
# math4        0
# year         0
# y93          0
# y94          0
# y95          0
# y96          0
# y97          0
# y98          0
# rexpp        0
# found        0
# lenrol       0
# lrexpp       0
# lavgrexpp    0
# dtype: int64

# %% [markdown]
# #### Observation

# %% [markdown]
# 1. Data had null values, which were replaced by mean
# 2. Data does not consist of any categorical value, hence every column's missing value can be replaced by mean

# %% [markdown]
# ## Univariate analysis

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10668 entries, 0 to 10667
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   distid     10668 non-null  int64
#  1   schid      10668 non-null  int64
#  2   lunch      10668 non-null  float64
#  3   enrol      10668 non-null  float64
#  4   exppp      10668 non-null  float64
#  5   math4      10668 non-null  float64
#  6   year       10668 non-null  int64
#  7   y93        10668 non-null  int64
#  8   y94        10668 non-null  int64
#  9   y95        10668 non-null  int64
#  10  y96        10668 non-null  int64
#  11  y97        10668 non-null  int64
#  12  y98        10668 non-null  int64
#  13  rexpp      10668 non-null  float64
#  14  found      10668 non-null  float64
#  15  lenrol     10668 non-null  float64
#  16  lrexpp     10668 non-null  float64
#  17  lavgrexpp  10668 non-null  float64
# dtypes: float64(9), int64(9)
# memory usage: 1.5 MB

# %%
cols = ["distid", "schid", "lunch", "enrol", "exppp", "math4", "rexpp", "found", "lenrol", "lrexpp", "lavgrexpp"]
for i in range(len(cols)):
  plt.subplot(1, 2, 1)
  sns.histplot(data[cols[i]], kde=True)
  plt.title("Distribution of " + cols[i])

  plt.subplot(1, 2, 2)
  sns.boxplot(x=data[cols[i]])
  plt.title("Box Plot of " + cols[i])

  plt.show()

# %%
binary_cols = ['y93', 'y94', 'y95', 'y96', 'y97', 'y98']

for col in binary_cols:
  sns.histplot(data['y93'])
  plt.xlabel(col)
  plt.ylabel("Frequency")
  plt.show()

# %% [markdown]
# ### Observation

# %% [markdown]
# 1. Count of lunch decreases as we go from 0 to 100
# 2. Enrol reaches the max value at 500, then decreases on going either direction.
# 3. Exppp, Math4, Rexpp, lenrol, lrexpp and lavegrexpp follows the similar trend as above
# 4. Outliers - enrol, expp, rexpp, found, lenrol, lrexpp, lavegrexpp
# 5. y93, y94 ... y98 consists of binary values

# %% [markdown]
# ## 2. Bivariate analysis

# %%
correlation = data.corr().abs()
print(correlation)
# Out:
#                  distid         schid     lunch     enrol     exppp     math4  \
# distid     1.000000e+00  2.461120e-02  0.018341  0.267705  0.076152  0.017160
# schid      2.461120e-02  1.000000e+00  0.121978  0.017332  0.009639  0.086886
# lunch      1.834110e-02  1.219783e-01  1.000000  0.046523  0.065038  0.468070
# enrol      2.677052e-01  1.733206e-02  0.046523  1.000000  0.162703  0.074697
# exppp      7.615153e-02  9.638716e-03  0.065038  0.162703  1.000000  0.260660
# math4      1.716025e-02  8.688562e-02  0.468070  0.074697  0.260660  1.000000
# year       5.390589e-14  3.970492e-13  0.027207  0.009388  0.526553  0.442625
# y93        1.121941e-17  1.651041e-16  0.020525  0.006867  0.383196  0.327456
# y94        2.011658e-17  5.078090e-16  0.015092  0.015038  0.243977  0.203367
# y95        5.517007e-17  6.588650e-16  0.002428  0.010356  0.008314  0.058514
# y96        6.056476e-17  1.117257e-15  0.006555  0.018772  0.112098  0.101373
# ...

# %%
high_correlation = []

for i in correlation.columns:
  for j in correlation.columns:
    if (i != j and correlation.loc[i, j] > 0.7):
      print(i, j, correlation.loc[i, j])
      high_correlation.append((i, j))
# Out:
# enrol lenrol 0.9062107293910491
# exppp rexpp 0.9889608352935018
# exppp lrexpp 0.9716529338126656
# exppp lavgrexpp 0.7684517511942496
# rexpp exppp 0.9889608352935018
# rexpp lrexpp 0.97606190200904
# rexpp lavgrexpp 0.7702629265482804
# lenrol enrol 0.9062107293910491
# lrexpp exppp 0.9716529338126656
# lrexpp rexpp 0.97606190200904
# lrexpp lavgrexpp 0.7396746640037307
# lavgrexpp exppp 0.7684517511942496
# lavgrexpp rexpp 0.7702629265482804
# lavgrexpp lrexpp 0.7396746640037307

# %%
for col in high_correlation:
  sns.scatterplot(x=data[col[0]], y=data[col[1]])
  plt.title(col[0] + " vs " + col[1])
  plt.show()

# %%
for col in data.columns:
  if (col != 'year'):
    sns.boxplot(x="year", y=col, data=data)
    plt.title("year vs " + col)
    plt.show()

# %% [markdown]
# ### Observation

# %% [markdown]
# 1. columns with high correlation:-
# enrol lenrol 0.9062107293910491
# exppp rexpp 0.9889608352935018
# exppp lrexpp 0.9716529338126656
# exppp lavgrexpp 0.7684517511942496
# rexpp exppp 0.9889608352935018
# rexpp lrexpp 0.97606190200904
# rexpp lavgrexpp 0.7702629265482804
# lenrol enrol 0.9062107293910491
# lrexpp exppp 0.9716529338126656
# lrexpp rexpp 0.97606190200904
# lrexpp lavgrexpp 0.7396746640037307
# lavgrexpp exppp 0.7684517511942496
# lavgrexpp rexpp 0.7702629265482804
# lavgrexpp lrexpp 0.7396746640037307
#
# 2. Initially as lenrol inc, enrol inc expontially. But beyound lenrol value 5, they both show linear relation
# 3. rexpp shows linear relation with exppp
# 4. From the above boxplots, we can observe that the year column is encoded using the one hot encoder to create columns - y93, y94 ... y98. Hence we can either drop year column or columns y93 to y98

# %% [markdown]
# ## Multivariate analysis

# %%
sns.pairplot(data, vars=['lunch', 'exppp', 'math4', 'rexpp', 'lenrol', 'lrexpp', 'lavgrexpp', 'found'], kind="reg")
plt.show()

# %%
sns.scatterplot(x="lunch", y="math4", hue="year", data=data)
plt.show()

# %% [markdown]
# Year had an impact on the correlation between math4 and lunch

# %%
sns.set(style="ticks", color_codes=True)
sns.pairplot(data, vars=['lunch', 'math4', 'exppp'], hue="year")
plt.show()

# %%
correlation = data.corr(method='pearson', numeric_only=True)
sns.heatmap(correlation, xticklabels=correlation.columns, yticklabels=correlation.columns)
plt.show()

# %% [markdown]
# ### Observation

# %% [markdown]
# 1. Math4 and lunch shows negative correlation - indicating as one inc, other decreases
# 2. rexpp and lexpp shows positive correlation - as one increases, other one also increases.
# 3. enrol and lenrol; expp and rexpp - +ve
# 4. all years show -ve correlation with each other
